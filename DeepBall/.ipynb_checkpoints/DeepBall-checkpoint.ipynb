# %%
import numpy as np
import tensorflow as tf
from keras import layers
from keras.layers import Conv2D
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.layers import ZeroPadding2D
from keras.layers import UpSampling2D
from keras.layers import MaxPooling2D
from keras.layers import Cropping2D
from keras.layers import ReLU
from keras.layers import Softmax
from keras.layers import Concatenate
from keras.layers import Dense
from keras.layers import Reshape
from keras import Model
from keras import backend as K
import xml.etree.ElementTree as ET
import os
import cv2
import math
import pickle as pkl
import imgaug as ia
import imgaug.augmenters as iaa
from imgaug.augmentables.heatmaps import HeatmapsOnImage
from tensorflow.python.client import device_lib
# %matplotlib notebook
import matplotlib.pyplot as plt
import time

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
print(tf.__version__)
print(tf.test.is_gpu_available()) # True/False

# Or only check for gpu's with cuda support
print(tf.test.is_gpu_available(cuda_only=True)) 
# print(device_lib.list_local_devices())
# K.tensorflow_backend._get_available_gpus()
# Out:
# 2.0.0
# True
# True

# %%
ANNOT = "..\\FIGC\\Annotation\\Film Role-0 ID-{} T-0 m00s00-026-m00s01-020.xgtf"
IMAGE = "..\\FIGC\\Sequence{}"
TRAIN_DIR = "..\\FIGC\\TrainDataset"
MAIN_DIR = "..\\FIGC"
sequences_train = {"1":{"flip":False},"3":{"flip":False},"4":{"flip":False}}
sequences_test = {"5":{"flip": False}, "6":{"flip": True}}
TEST_DIR = "..\\FIGC\\TestDataset"

# %%
class Dataset:
    def __init__(self, sequences, augment=True):
        self.ns = {"base":"http://lamp.cfar.umd.edu/viper#",
                         "data":"http://lamp.cfar.umd.edu/viperdata#"}
        self.images = []
        self.imageopts = []
        self.augment = augment
        self.labels = None
        for seq,opt in sequences.items():
            curr_images = os.listdir(IMAGE.format(seq))
            seq_size = len(curr_images)
            self.images.extend([os.path.join(IMAGE.format(seq), i) for i in curr_images])
            self.imageopts.extend([opt] * seq_size)
            annotation_file = ANNOT.format(seq)  
            tree = ET.parse(annotation_file)
            
            root = tree.getroot()
            Ball = root.find(".//base:object[@name='BALL']", self.ns)
            frames = int(Ball.attrib['framespan'].split(':')[1])
            curr_labels = np.full((seq_size, 2), -1, dtype=np.int16)
            BallPos = Ball.find("./*[@name='BallPos']")
            for datapoint in BallPos.findall('data:point', self.ns):
                frameno = int(datapoint.get('framespan').split(':')[0])
                if frameno > seq_size + 7:
                    break
                x,y = int(datapoint.get('x')), int(datapoint.get('y'))
                curr_labels[frameno-1-7] = np.array([x,y])
                
            if self.labels is None:
                self.labels = curr_labels
            else:
                self.labels = np.concatenate((self.labels, curr_labels), axis=0)
                
        assert len(self.images) == self.labels.shape[0]
        assert len(self.imageopts) == self.labels.shape[0]
    
    def generate_batches(self, batch_size=16):
        set_size = len(self.images)
        image_batch = []
        map_batch = []
        for i in range(set_size):
            y_true = np.concatenate((np.zeros((68,120,1), dtype=np.float32), np.ones((68,120,1), dtype=np.float32)), axis=-1)
            img = cv2.imread(self.images[i], 1)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            H,W,_ = img.shape
            if H < 1088 or W < 1920:
                img = np.pad(img, ((0,1088-H),(0,1920-W),(0,0)), 'constant', constant_values=0)
            if self.imageopts[i].get("flip") == True:
                img = cv2.flip(img, 1)
                
            x,y = self.labels[i]
            visible = False if x < 0 else True
            
            x,y = int(math.floor((int(x)-1)/16)), int(math.floor((int(y)-1)/16))
            if visible:
                # Label ground truth location with ball confidence 1 and bg confidence 0
                y_true[y,x,0] = 1
                y_true[y,x,1] = 0
                # Expand background confidence to neighbours
                bg_kernel = np.ones((3,3), dtype=np.uint8)
                y_true[:,:,1] = cv2.erode(y_true[:,:,1], bg_kernel, iterations=1)
            
            # Input images being resized to 480 by 272 to improve performance
            image_batch.append(cv2.resize(img, dsize=(480,272)))
            map_batch.append(y_true)
            if len(image_batch) == batch_size:
                yield (np.asarray(image_batch), np.asarray(map_batch))
                
                if self.augment:
                    # Image Augmentation 
                    seq = iaa.Sequential([
                        iaa.OneOf([
                            iaa.MultiplyBrightness((0.5,1.5)),
                            iaa.MultiplyHue((0.5,1.5)),
                            iaa.MultiplySaturation((0.5,1.5)),
                            iaa.LinearContrast((0.4,1.6))
                        ]),
                        iaa.Fliplr(0.5),
                        iaa.Crop(percent=(0.0,0.25))
                    ])
                    images_aug, maps_aug = seq(images=image_batch, heatmaps=map_batch)

                    yield (np.asarray(images_aug), np.asarray(maps_aug))
                
                image_batch.clear()
                map_batch.clear()
        if image_batch:
            yield (np.asarray(image_batch), np.asarray(map_batch))
            
            if self.augment:
                # Image Augmentation 
                seq = iaa.Sequential([
                        iaa.OneOf([
                            iaa.MultiplyBrightness((0.5,1.5)),
                            iaa.MultiplyHue((0.5,1.5)),
                            iaa.MultiplySaturation((0.5,1.5)),
                            iaa.LinearContrast((0.4,1.6))
                        ]),
                        iaa.Fliplr(0.5),
                        iaa.Crop(percent=(0.0,0.25))
                    ])
                images_aug, maps_aug = seq(images=image_batch, heatmaps=map_batch)

                yield (np.asarray(images_aug), np.asarray(maps_aug))
            
            del image_batch, map_batch
            
    def load(self, DIR):
        file_list = os.listdir(DIR)
        # Infinitely iterable as Keras requires
        while True:
            for file in file_list:
                with open(os.path.join(DIR, file), 'rb') as f:
                    x_train, y_train = pkl.load(f)
                    yield (x_train, y_train)

# %%
def deepball_loss_function(y_true, y_pred):
    # y_true (batch_size, 68, 120, 2)
    # y_pred (batch_size, 68, 120, 2)
    
    ball_gt, bg_gt = y_true[:,:,:,0], y_true[:,:,:,1]
    N = K.sum(ball_gt, axis=(1,2)) + 1
    M = K.sum(bg_gt, axis=(1,2)) + 1
    zer = K.zeros_like(ball_gt)
    
    y_pred = K.log(y_pred)
    ball_cm = y_pred[:,:,:,0]
    bg_cm = y_pred[:,:,:,1]
    
    Lpos = K.sum(zer + (ball_cm * ball_gt), axis=(1,2))
    Lpos = K.sum(K.zeros_like(N) + (Lpos / N))
    
    Lneg = K.sum(zer + (bg_cm * bg_gt), axis=(1,2))
    Lneg = K.sum(K.zeros_like(M) + (Lneg / M))
#     print(K.eval(Lpos),K.eval(Lneg))

    # Multiplying by batch_size as Keras automatically averages the scalar output over it
    return (-Lpos - 0.2*Lneg) * 16

# %%
def deepball_precision(y_true, y_pred):
    ball_gt = y_true[:,:,:,0]
    ball_cm = y_pred[:,:,:,0]
    
    thre_ball_cm = K.cast(K.greater(ball_cm, 0.5), "float32")
    tp = K.sum(ball_gt * thre_ball_cm)
    totalp = K.sum(K.max(thre_ball_cm, axis=(1,2)))
    
    return tp/tf.maximum(1.0, totalp)

# %%
def peak_tp_confidence(y_true, y_pred):
    ball_gt = y_true[:,:,:,0]
    ball_cm = y_pred[:,:,:,0]
    N = K.sum(ball_gt, axis=(1,2))
    num_tp = K.sum(N)
    peak_c = K.max(ball_cm, axis=(1,2))
    
    return K.sum((N * peak_c)) / tf.maximum(1.0, num_tp)

# %%
def peak_fp_confidence(y_true, y_pred):
    ball_gt = y_true[:,:,:,0]
    ball_cm = y_pred[:,:,:,0]
    N = 1 - K.sum(ball_gt, axis=(1,2))
    num_fp = K.sum(N)
    peak_c = K.max(ball_cm, axis=(1,2))
    
    return K.sum((N * peak_c)) / tf.maximum(1.0, num_fp)

# %%
y = np.concatenate((np.zeros((16,68,120,1)), np.ones((16,68,120,1))), axis=-1)
y[:,48,52] = np.array([1,0])
y_pred = K.random_uniform_variable(shape=(16,68,120,2), low=0,high=1)
y_true = K.variable(value=y)

# %%
loss = deepball_loss_function(y_true, y_pred)
print(K.eval(loss))
prec = deepball_precision(y_true, y_pred)
print(K.eval(prec))

pt = peak_tp_confidence(y_true, y_pred)
print(K.eval(pt))
pf = peak_fp_confidence(y_true, y_pred)
print(K.eval(pf))
# Out:
# 178.6196
# 0.625
# 0.9999164
# 0.0

# %%
## Functional API model

def _conv_block(inp, convs, pool=True):
    x = inp
    count = 0
    for conv in convs:
        count += 1
        x = Conv2D(conv['filter'],
                   conv['kernel'],
                   strides=conv['stride'],
                   padding='same',
                   name='conv_' + str(conv['layer_idx']),
                   use_bias=False)(x)
        x = BatchNormalization(epsilon=0.001, name='bnorm_' + str(conv['layer_idx']))(x)
        x = ReLU()(x)
    if pool:
        x = MaxPooling2D(pool_size=2)(x)
    return x

def get_functional_deepball_model():
    #Input image
    input_image = Input(shape=(272, 480, 3))

    # Conv1
    x = _conv_block(input_image, [{'filter': 8, 'kernel': 7, 'stride': 2, 'layer_idx': 0},
                                  {'filter': 8, 'kernel': 3, 'stride': 1, 'layer_idx': 1}])
    conv1 = x
    # Conv2
    x = _conv_block(x, [{'filter': 16, 'kernel': 3, 'stride': 1, 'layer_idx': 2},
                        {'filter': 16, 'kernel': 3, 'stride': 1, 'layer_idx': 3}])
    conv2 = x

    # Conv3
    x = _conv_block(x, [{'filter': 32, 'kernel': 3, 'stride': 1, 'layer_idx': 4},
                        {'filter': 32, 'kernel': 3, 'stride': 1, 'layer_idx': 5}])
    conv3 = x

    # Upsampling Conv2
    upsampled_conv2 = UpSampling2D(size=(2,2))(conv2)

    # Upsampling Conv3
    upsampled_conv3 = UpSampling2D(size=(4,4))(conv3)

    # Concatenation along channels axis
    concat = Concatenate(axis=-1)([conv1, upsampled_conv2, upsampled_conv3])
    x = concat

    # Conv4
    x = _conv_block(x, [{'filter': 56, 'kernel': 3, 'stride': 1, 'layer_idx':6},
                        {'filter': 2, 'kernel': 3, 'stride': 1, 'layer_idx': 7}], pool=False)
    
#     conv3c = Reshape((32*30*17,))(conv3)
#     cout = Dense(1, activation='sigmoid')(Dense(200, activation='relu')(conv3c))
    
    x = Softmax(axis=-1)(x)
    model = Model(inputs=input_image, outputs=x)
    
    return model

# %%
# Subclassed Model - has some issues but more extensible
# class ConvBlock(layers.Layer):
#     def __init__(self, convs, pool=True):
#         super(ConvBlock, self).__init__()
#         self.convs = convs
#         self.conv1 = Conv2D(convs[0]['filter'],
#                        convs[0]['kernel'],
#                        strides=convs[0]['stride'],
#                        padding='same',
#                        name='conv_' + str(convs[0]['layer_idx']),
#                        use_bias=False)
#         self.bnorm1 = BatchNormalization(epsilon=0.001, name='bnorm_' + str(convs[0]['layer_idx']))
#         self.relu1 = ReLU()
        
#         self.conv2 = Conv2D(convs[1]['filter'],
#                        convs[1]['kernel'],
#                        strides=convs[1]['stride'],
#                        padding='same',
#                        name='conv_' + str(convs[1]['layer_idx']),
#                        use_bias=False)
#         self.bnorm2 = BatchNormalization(epsilon=0.001, name='bnorm_' + str(convs[1]['layer_idx']))
#         self.relu2 = ReLU()
        
#         self.pool = pool
   
#     def call(self, inputs):
#         x = self.relu1(self.bnorm1(self.conv1(inputs)))
#         x = self.relu2(self.bnorm2(self.conv2(x)))
#         if self.pool:
#             x = MaxPool2D(pool_size=2)(x)
#         return x
    
#     def get_config(self):
#         config = super(ConvBlock, self).get_config()
#         config.update({"convs": self.convs, "pool": self.pool})
#         return config

# class DeepBall(keras.Model): 
#     def __init__(self):
#         super(DeepBall, self).__init__()
#         self.conv_block1 = ConvBlock([{'filter': 8, 'kernel': 7, 'stride': 2, 'layer_idx': 0},
#                                   {'filter': 8, 'kernel': 3, 'stride': 1, 'layer_idx': 1}])
       
#         # Conv2
#         self.conv_block2 = ConvBlock([{'filter': 16, 'kernel': 3, 'stride': 1, 'layer_idx': 2},
#                             {'filter': 16, 'kernel': 3, 'stride': 1, 'layer_idx': 3}])
       
#         # Conv3
#         self.conv_block3 = ConvBlock([{'filter': 32, 'kernel': 3, 'stride': 1, 'layer_idx': 4},
#                             {'filter': 32, 'kernel': 3, 'stride': 1, 'layer_idx': 5}])
        
#         # Upsampling Conv2 by 2x
#         self.ups_block2 = UpSampling2D(size=(2,2))

#         # Upsampling Conv3 by 4x
#         self.ups_block3 = UpSampling2D(size=(4,4))

#         # Concatenation along channels axis
#         self.concat = Concatenate(axis=-1)
       

#         # Classification Conv4
#         self.conv_block4 = ConvBlock([{'filter': 56, 'kernel': 3, 'stride': 1, 'layer_idx':6},
#                             {'filter': 2, 'kernel': 3, 'stride': 1, 'layer_idx': 7}], pool=False)
#         # Softmax to output probability
#         self.softmax = Softmax(axis=-1)
        
#     def call(self, inputs):
#         x = self.conv_block1(inputs)
#         c1 = x
#         x = self.conv_block2(x)
#         c2 = x
#         x = self.conv_block3(x)
#         c3 = x
#         up2 = self.ups_block2(c2)
#         up3 = self.ups_block3(c3)
        
#         x = self.concat([c1, up2, up3])
#         x = self.conv_block4(x)
        
#         x = self.softmax(x)
        
#         return x
    
#     def model(self):
#         x = Input(shape=(272,480,3))
#         return keras.Model(inputs=x, outputs=self.call(x))

# %%
def create_batches(dataset, DIR):
    d_generator = dataset.generate_batches(batch_size=16)
    batchno = 1
    for x_train, y_train in d_generator:
        with open(os.path.join(DIR, '{}.pkl'.format(batchno)), 'wb') as f:
            pkl.dump([x_train, y_train], f)
        print('saved to disk: {}'.format(batchno))
        batchno+=1

def get_compiled_deepball_model():
    # define the model
    model = get_functional_deepball_model()
#     model.summary()
    model.compile(optimizer='adam', loss=deepball_loss_function, 
                  metrics=[deepball_precision])
    return model

def train(train_dataset, model):
    train_loader = train_dataset.load(TRAIN_DIR)
    model.fit_generator(train_loader, epochs=75, verbose=2, steps_per_epoch=1126)

    model.save_weights('deepball_weights.h5')

# %%
train_dataset = Dataset(sequences_train)

# %%
# create_batches(train_dataset, TRAIN_DIR)

# %%
model = get_compiled_deepball_model()
train(train_dataset, model)
# Out:
# Epoch 1/75
#  - 89s - loss: 25.0661 - deepball_precision: 0.3759
# Epoch 2/75
#  - 66s - loss: 14.2641 - deepball_precision: 0.3839
# Epoch 3/75
#  - 67s - loss: 9.9958 - deepball_precision: 0.3829
# Epoch 4/75
#  - 66s - loss: 8.1081 - deepball_precision: 0.3835
# Epoch 5/75
#  - 66s - loss: 6.9042 - deepball_precision: 0.3848
# Epoch 6/75
#  - 66s - loss: 6.3694 - deepball_precision: 0.3838
# Epoch 7/75
#  - 66s - loss: 5.4990 - deepball_precision: 0.3851
# Epoch 8/75
#  - 66s - loss: 4.9174 - deepball_precision: 0.3864
# Epoch 9/75
#  - 66s - loss: 4.4387 - deepball_precision: 0.3865
# Epoch 10/75
#  - 66s - loss: 4.6627 - deepball_precision: 0.3871
# Epoch 11/75
#  - 66s - loss: 4.3048 - deepball_precision: 0.3879
# Epoch 12/75
#  - 66s - loss: 4.0192 - deepball_precision: 0.3872
# Epoch 13/75
#  - 66s - loss: 3.4676 - deepball_precision: 0.3885
# Epoch 14/75
#  - 66s - loss: 3.4763 - deepball_precision: 0.3879
# Epoch 15/75
#  - 66s - loss: 3.2200 - deepball_precision: 0.3883
# Epoch 16/75
#  - 66s - loss: 3.8984 - deepball_precision: 0.3874
# Epoch 17/75
#  - 66s - loss: 2.9074 - deepball_precision: 0.3887
# Epoch 18/75
#  - 66s - loss: 2.7310 - deepball_precision: 0.3891
# Epoch 19/75
#  - 67s - loss: 2.4984 - deepball_precision: 0.3898
# Epoch 20/75
#  - 67s - loss: 2.4640 - deepball_precision: 0.3899
# Epoch 21/75
#  - 66s - loss: 2.2597 - deepball_precision: 0.3899
# Epoch 22/75
#  - 66s - loss: 1.9998 - deepball_precision: 0.3907
# Epoch 23/75
#  - 66s - loss: 2.1176 - deepball_precision: 0.3909
# Epoch 24/75
#  - 66s - loss: 2.2481 - deepball_precision: 0.3908
# Epoch 25/75
#  - 66s - loss: 2.2150 - deepball_precision: 0.3904
# Epoch 26/75
#  - 66s - loss: 2.0187 - deepball_precision: 0.3904
# Epoch 27/75
#  - 66s - loss: 1.8439 - deepball_precision: 0.3906
# Epoch 28/75
#  - 66s - loss: 1.4368 - deepball_precision: 0.3923
# Epoch 29/75
#  - 66s - loss: 1.6674 - deepball_precision: 0.3916
# Epoch 30/75
#  - 66s - loss: 2.0345 - deepball_precision: 0.3908
# Epoch 31/75
#  - 66s - loss: 1.5700 - deepball_precision: 0.3918
# Epoch 32/75
#  - 66s - loss: 1.2244 - deepball_precision: 0.3925
# Epoch 33/75
#  - 66s - loss: 1.6637 - deepball_precision: 0.3915
# Epoch 34/75
#  - 66s - loss: 1.5644 - deepball_precision: 0.3918
# Epoch 35/75
#  - 66s - loss: 1.1925 - deepball_precision: 0.3923
# Epoch 36/75
#  - 66s - loss: 1.1594 - deepball_precision: 0.3939
# Epoch 37/75
#  - 66s - loss: 1.6989 - deepball_precision: 0.3914
# Epoch 38/75
#  - 67s - loss: 1.3835 - deepball_precision: 0.3916
# Epoch 39/75
#  - 67s - loss: 1.0869 - deepball_precision: 0.3927
# Epoch 40/75
#  - 66s - loss: 1.0354 - deepball_precision: 0.3933
# Epoch 41/75
#  - 66s - loss: 1.2009 - deepball_precision: 0.3923
# Epoch 42/75
#  - 66s - loss: 0.9181 - deepball_precision: 0.3939
# Epoch 43/75
#  - 66s - loss: 0.9439 - deepball_precision: 0.3951
# Epoch 44/75
#  - 66s - loss: 1.0868 - deepball_precision: 0.3927
# Epoch 45/75
#  - 66s - loss: 1.1292 - deepball_precision: 0.3933
# Epoch 46/75
#  - 66s - loss: 0.8759 - deepball_precision: 0.3953
# Epoch 47/75
#  - 66s - loss: 1.2403 - deepball_precision: 0.3929
# Epoch 48/75
#  - 66s - loss: 1.2292 - deepball_precision: 0.3928
# Epoch 49/75
#  - 66s - loss: 1.0076 - deepball_precision: 0.3937
# Epoch 50/75
#  - 66s - loss: 0.7988 - deepball_precision: 0.3952
# Epoch 51/75
#  - 66s - loss: 0.7060 - deepball_precision: 0.3981
# Epoch 52/75
#  - 67s - loss: 0.8586 - deepball_precision: 0.3940
# Epoch 53/75
#  - 66s - loss: 0.6097 - deepball_precision: 0.3988
# Epoch 54/75
#  - 66s - loss: 0.7359 - deepball_precision: 0.3973
# Epoch 55/75
#  - 66s - loss: 0.8170 - deepball_precision: 0.3967
# Epoch 56/75
#  - 66s - loss: 0.8454 - deepball_precision: 0.3951
# Epoch 57/75
#  - 66s - loss: 0.6078 - deepball_precision: 0.3990
# Epoch 58/75
#  - 66s - loss: 0.7507 - deepball_precision: 0.3999
# Epoch 59/75
#  - 66s - loss: 0.7070 - deepball_precision: 0.3997
# Epoch 60/75
#  - 66s - loss: 0.7989 - deepball_precision: 0.3981
# Epoch 61/75
#  - 66s - loss: 0.7802 - deepball_precision: 0.3971
# Epoch 62/75
#  - 67s - loss: 0.8411 - deepball_precision: 0.3949
# Epoch 63/75
#  - 66s - loss: 0.7069 - deepball_precision: 0.3954
# Epoch 64/75
#  - 66s - loss: 0.5536 - deepball_precision: 0.3996
# Epoch 65/75
#  - 66s - loss: 0.4602 - deepball_precision: 0.4058
# Epoch 66/75
#  - 67s - loss: 0.5020 - deepball_precision: 0.4045
# Epoch 67/75
#  - 66s - loss: 0.8430 - deepball_precision: 0.3995
# Epoch 68/75
#  - 66s - loss: 0.7115 - deepball_precision: 0.3967
# Epoch 69/75
#  - 66s - loss: 0.5864 - deepball_precision: 0.4005
# Epoch 70/75
#  - 66s - loss: 0.5383 - deepball_precision: 0.4029
# Epoch 71/75
#  - 66s - loss: 0.6098 - deepball_precision: 0.3995
# Epoch 72/75
#  - 66s - loss: 0.4231 - deepball_precision: 0.4053
# Epoch 73/75
#  - 66s - loss: 0.5855 - deepball_precision: 0.4017
# Epoch 74/75
#  - 66s - loss: 0.7669 - deepball_precision: 0.3955
# Epoch 75/75
#  - 66s - loss: 0.4429 - deepball_precision: 0.4032

# %%
# dmodel.compile(optimizer='adam', loss=deepball_loss_function, 
#                   metrics=[deepball_precision, peak_tp_confidence, peak_fp_confidence])
# train_loader = train_dataset.load(TRAIN_DIR)
# dmodel.fit_generator(train_loader, epochs=75, verbose=2, steps_per_epoch=1126)

# dmodel.save_weights('deepballmini3.h5')
#keras.models.save_model(dmodel, "deepballModel.hp5", save_format="h5")

# %%
test_dataset = Dataset(sequences_test, augment=False)
# create_batches(test_dataset, TEST_DIR)

# %%
test_load = test_dataset.load(TEST_DIR)
testmodel = get_compiled_deepball_model()
testmodel.load_weights('deepball_weights.h5')
evaluation = testmodel.evaluate_generator(test_load, steps=375, verbose=1)
print(evaluation)
# Out:
# 375/375 [==============================] - 30s 81ms/step
# [0.12973710894584656, 0.08733333647251129]

# %%
def testNet(model):
    sampimg = cv2.imread(os.path.join(MAIN_DIR, "Sequence6", "0010.bmp"), 1)
    sampimg = cv2.cvtColor(sampimg, cv2.COLOR_BGR2RGB)
    H,W,_ = sampimg.shape

    cmap = model.predict(np.array([cv2.resize(sampimg, (480,272))]), batch_size=1, verbose=1)
#     cmap = K.exp(cmap)

    ball_cm = cmap[0,:,:,0]
    bg_cm = cmap[0,:,:,1]
    
    pos = np.unravel_index(np.argmax(ball_cm, axis=None), ball_cm.shape)
    yp, xp = pos
    print(xp, yp)
    yp, xp = int(math.floor(16*yp)), int(math.floor(16*xp))
    print(xp, yp)
    print('Peak ball C : {}'.format(ball_cm[pos]))
    plt.figure(figsize=(8,10))
    plt.subplot(3,1,1)
    plt.imshow(bg_cm, cmap='gray')
    plt.subplot(3,1,2)
    plt.imshow(ball_cm, cmap='gray')
    plt.subplot(3,1,3)
    cv2.circle(sampimg, (xp,yp), 16, (43,0,255), thickness=2)
    plt.imshow(sampimg)
    plt.show()

# %%
testNet(testmodel)
# Out:
# 1/1 [==============================] - 0s 131ms/sample
# 91 4
# 1456 64
# Peak ball C : 0.9999494552612305
# <img src="data:image/png;base64,..." width="800">

# %%
def display_ball_box(image, x, y):
    if x < 0:
        print("*** No ball detected ***")
    else:
        ball_pos = np.array([y,x])
        cv2.circle(image, (x, y), 16, (255,0,0), thickness=2)
    return image

# %%
def ballTrack(cap, output, model):
    trackers = []
    i = 0
    frame_rate_divider = 1
#     bpos = deque()
    while(cap.isOpened()):
        stime = time.time()
        ret, frame = cap.read()
        if ret:
            if i % frame_rate_divider == 0:
                rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                
                (h, w) = frame.shape[:2]
                ky, kx = 4 * h/272.0, 4 * w/480.0
                cmap = model.predict(np.array([cv2.resize(frame, (480,272))]), batch_size=1, verbose=1)
                cm = cmap[0,:,:,0]
                pos = np.unravel_index(np.argmax(cm, axis=None), cm.shape)
                y,x = pos
                x = -1 if cm[y,x] < 0.998 else x
                print(cm[y,x])
                y,x = math.floor(ky * y), math.floor(kx * x)
                
                frame = display_ball_box(frame, x, y)
#                 bpos.append((y,x))
                output.write(frame)
                cv2.imshow('frame', frame)
                i += 1
                
            print('FPS {:.1f}'.format(1 / (time.time() - stime)))

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        else:
            break
    cap.release()
    output.release()
    cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture('Seq6.avi')
size = (
	int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
	int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
)
codec = cv2.VideoWriter_fourcc(*'DIVX')
output = cv2.VideoWriter('Seq6Ball.avi',codec,25.0,size)
# outputSeg = cv2.VideoWriter('Seq6Seg.avi', codec,25.0,size)

# %%
ballTrack(cap,output,testmodel)
# Out:
# 1/1 [==============================] - 0s 9ms/step
# 0.9990453
# FPS 10.1
# 1/1 [==============================] - 0s 4ms/step
# 0.99914765
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9992861
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9992638
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9990594
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99915946
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99928147
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9991641
# FPS 43.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99852127
# FPS 38.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99871504
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9986738
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99864155
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99880135
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99860746
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.998379
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9981511
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0002090313
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00022118511
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00021224689
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00020862851
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.00020790113
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00021648212
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.0002089253
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.00021692346
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0002109096
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00020678317
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00019768142
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00020214023
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 3ms/step
# 0.00019957531
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00021076023
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.00016408012
# *** No ball detected ***
# FPS 28.6
# 1/1 [==============================] - 0s 4ms/step
# 0.0001576971
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0016704161
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.0001629384
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0017016004
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.001786203
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0017991901
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 5ms/step
# 0.0017489392
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0017687607
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.0018626855
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0017727485
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.0018352991
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.0017368831
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.0014853163
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0014680399
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0013152281
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013726063
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 3ms/step
# 0.0001422009
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013796816
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 5ms/step
# 0.0009243138
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.0009555634
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014092891
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0001347862
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00013307847
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013038953
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00014394712
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014649106
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013949609
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0001430566
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0010278955
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.00014633623
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00014297017
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014065222
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013700918
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00013707792
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 5ms/step
# 0.00013186055
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.00013143699
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014480867
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.00014551484
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.0007015487
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0006915085
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015056683
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00015145974
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9981325
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9985623
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9990287
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9986563
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99825627
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00016579151
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0001783092
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00017580677
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00018054937
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00018529446
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00017720547
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.0001778565
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016574013
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00018088367
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00016330485
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00015990718
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00017419104
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00016171408
# *** No ball detected ***
# FPS 31.2
# 1/1 [==============================] - 0s 4ms/step
# 0.0001576332
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00015960376
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.000150119
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00014929318
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9980731
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9992834
# FPS 38.4
# 1/1 [==============================] - 0s 3ms/step
# 0.99801815
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006511615
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.0006567627
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015367827
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9987214
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015007734
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015782811
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015903225
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9980451
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99822944
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9985336
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99856573
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99812275
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99800044
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9985695
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99804115
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99813265
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99881697
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9994431
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99972945
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9997831
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9998041
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99985373
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.999864
# FPS 40.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9997353
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9996177
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9989053
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9982389
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00014264442
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99827063
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9987225
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99864715
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9985812
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006749307
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00012915456
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9988826
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00014188694
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00012466668
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00013162765
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00014826989
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015390087
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.00015744692
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.00014443893
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001596269
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.00015892585
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00015923254
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015096719
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00014911094
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.00014840299
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00027660216
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.00029036123
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015475864
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99863005
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9993487
# FPS 29.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99856865
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99880826
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993331
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99955636
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9996039
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99964845
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99936527
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9982218
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00015281365
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9982849
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99915457
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9991079
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00014957131
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001474374
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016041758
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99901783
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99958676
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.998467
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.00015779847
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00016080198
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00016471828
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9988655
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99863356
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99891126
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.998831
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9989973
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99897814
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9995078
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9995988
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00017285087
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.00018408691
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00018204833
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99883384
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.998097
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9984806
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9987219
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993699
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9995072
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.99954957
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99954236
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.999629
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9995747
# FPS 40.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9994168
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99951077
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9993988
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99943787
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99957484
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99950325
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9993476
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99932504
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9990307
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99928963
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9991592
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9991634
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9988966
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99875367
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9982828
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99823797
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99822587
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99817574
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99805117
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9984856
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99827456
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99840134
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.99840873
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99857783
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9984144
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99829954
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9984596
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0006883377
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9983271
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9982882
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0006433682
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.9980667
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00068752246
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99800533
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00070939516
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00070262526
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0006751132
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0007111432
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00069835945
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00014987557
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00015004272
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00015886128
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016307471
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00066116534
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.00016209757
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00065977057
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016925331
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00069633446
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.00068718055
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.0007494036
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0007754823
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.0007219792
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0007228346
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.00076285313
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0006921899
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00074316154
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.000722898
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99853814
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99922097
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9997241
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0006282416
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006948847
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00062917185
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00066394627
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00064625527
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006451064
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.0006501135
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.0006712154
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006400579
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9982058
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9981729
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99825007
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.9981987
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9982514
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9980336
# FPS 31.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9983261
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9980367
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9985728
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9987703
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.99879175
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.998787
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9988312
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99879384
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99852175
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99867225
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9985404
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99856156
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9986363
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9984951
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9983388
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.998993
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9990233
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99888915
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.99839956
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00068483833
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006708752
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 3ms/step
# 0.0006581869
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.000650309
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00066285976
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006875215
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0007192536
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0006517721
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0006602036
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006577116
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.0006175228
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.00064152124
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00064137054
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00066540384
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00063070824
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0006192709
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.00060571684
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 5ms/step
# 0.00062086596
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.000659361
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0006885099
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00065870845
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00067089824
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006554127
# *** No ball detected ***
# FPS 31.2
# 1/1 [==============================] - 0s 4ms/step
# 0.0006677455
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00074372947
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00066941616
# *** No ball detected ***
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00070808176
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0006904016
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00069548265
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0006994252
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0001513607
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00017289683
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.0007219387
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00072816305
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00014469768
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.0006580145
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00073835783
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9980405
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.998097
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99804866
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00067397684
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9981615
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0007584525
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9984444
# FPS 29.4
# 1/1 [==============================] - 0s 5ms/step
# 0.9982463
# FPS 32.2
# 1/1 [==============================] - 0s 5ms/step
# 0.99814725
# FPS 32.3
# 1/1 [==============================] - 0s 5ms/step
# 0.998207
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.99807966
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9980426
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00065184815
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.99850357
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99849844
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99854434
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9987431
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9987607
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99878067
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99857414
# FPS 32.3
# 1/1 [==============================] - 0s 5ms/step
# 0.9980421
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00065212033
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.0001749307
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00019124683
# *** No ball detected ***
# FPS 31.2
# 1/1 [==============================] - 0s 4ms/step
# 0.00017772631
# *** No ball detected ***
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.00017429388
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00017535892
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00017155356
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00016561378
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016663673
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00015810135
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00016554318
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001584791
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00015689796
# *** No ball detected ***
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00015723074
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.00016221446
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.00015064783
# *** No ball detected ***
# FPS 38.4
# 1/1 [==============================] - 0s 5ms/step
# 0.00015544427
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00015086503
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.00014881135
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00015322569
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00016611352
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001574073
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99938333
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001650305
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00016017302
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016642713
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.00016256487
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99817693
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00017259063
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00017738738
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00018115396
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.00017025671
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00017184348
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9980475
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00016989281
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00016898918
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.00016548116
# *** No ball detected ***
# FPS 30.3
# 1/1 [==============================] - 0s 5ms/step
# 0.00016561864
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00017811413
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001665608
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9997633
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99828476
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99820924
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99815935
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9985728
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99869055
# FPS 28.6
# 1/1 [==============================] - 0s 4ms/step
# 0.9990073
# FPS 32.2
# 1/1 [==============================] - 0s 5ms/step
# 0.9991979
# FPS 31.2
# 1/1 [==============================] - 0s 3ms/step
# 0.99917537
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9989146
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.998816
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99929607
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99848
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9998246
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999989
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9998498
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99834704
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9995177
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0001675174
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99944955
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9991314
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9998374
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9997931
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99997795
# FPS 40.0
# 1/1 [==============================] - 0s 3ms/step
# 0.00067549513
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9981609
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99895453
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99931586
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99919564
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9990055
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99943024
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9986828
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9986305
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999902
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.9999999
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999914
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9999999
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999951
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999917
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99999785
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999595
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9999993
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999964
# FPS 38.5
# 1/1 [==============================] - 0s 3ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99999917
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999905
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99970585
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999671
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9996032
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99912566
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9992459
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99980396
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9998921
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.999995
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99814415
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992211
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999722
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9999498
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999993
# FPS 29.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99998
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.99998677
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999987
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.999995
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99999774
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999917
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999995
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999666
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 1.0
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999981
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999778
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999917
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999905
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999993
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999905
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999993
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999989
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999994
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999917
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.999998
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9999995
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999995
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999974
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999905
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9999776
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9999982
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 38.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9999571
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99993706
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999969
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9997762
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.998615
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.999951
# FPS 32.3
# 1/1 [==============================] - 0s 5ms/step
# 0.999997
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9999995
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99999964
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99999905
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999951
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9993197
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99968565
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.999954
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999785
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9999989
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99999404
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999918
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99994445
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9999523
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99952304
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00012421649
# *** No ball detected ***
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.999977
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999969
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9999951
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99998796
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9998621
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9986645
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9988813
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9990864
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9993754
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9998481
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99999905
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999969
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999994
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9992613
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99993443
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.99996054
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99916625
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9998982
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99989605
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9996991
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99993277
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99999464
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999907
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999845
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99999774
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999404
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999917
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9999981
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999905
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999989
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999665
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999957
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999908
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99998975
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999975
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999995
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999845
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999734
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99996674
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999981
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999982
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999964
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 1.0
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999964
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99999976
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999752
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999584
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.9999924
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9999745
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999857
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99999726
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99999714
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99999845
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999945
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99999905
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 1.0
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999714
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99998987
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999968
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999906
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999969
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99999535
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9999999
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9999994
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.99999225
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9999949
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99999475
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.99999464
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99999833
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999988
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9999982
# FPS 35.7
# ...
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99829835
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9981238
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00015047955
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9987226
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9983949
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9987225
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99904937
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99823964
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00015176319
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00015355318
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.00016898836
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.0001600434
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99867165
# FPS 29.4
# 1/1 [==============================] - 0s 4ms/step
# 0.9983077
# FPS 31.2
# 1/1 [==============================] - 0s 3ms/step
# 0.99864
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99855703
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9984693
# FPS 33.3
# 1/1 [==============================] - 0s 3ms/step
# 0.9989593
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9991302
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99874926
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9988355
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9991347
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.9990343
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99904376
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9989343
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99879897
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9985393
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9985202
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9983669
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99822336
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9981133
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9984694
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99862206
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.998939
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9987368
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.998995
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9989968
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99908996
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9990754
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9990552
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99867505
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99851197
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99962914
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9994785
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9991442
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9992046
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9993591
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993992
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99948955
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99950624
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99931014
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9996263
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.999584
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9995987
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99960476
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9996076
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99942374
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99949694
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99951065
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9994661
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99958545
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9994473
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993444
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99920815
# FPS 31.2
# 1/1 [==============================] - 0s 4ms/step
# 0.99926645
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99940217
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99945265
# FPS 37.0
# 1/1 [==============================] - 0s 5ms/step
# 0.99914324
# FPS 32.2
# 1/1 [==============================] - 0s 5ms/step
# 0.9991161
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9990324
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99910825
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99903834
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99868304
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9982805
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99851173
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99873215
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9988945
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9990711
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99901676
# FPS 37.0
# 1/1 [==============================] - 0s 5ms/step
# 0.9994005
# FPS 32.2
# 1/1 [==============================] - 0s 5ms/step
# 0.9991478
# FPS 32.2
# 1/1 [==============================] - 0s 5ms/step
# 0.9993749
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9991117
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992225
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99920887
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992366
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9992624
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992101
# FPS 34.5
# 1/1 [==============================] - 0s 10ms/step
# 0.99892116
# FPS 27.8
# 1/1 [==============================] - 0s 4ms/step
# 0.9988267
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99917835
# FPS 37.0
# 1/1 [==============================] - 0s 3ms/step
# 0.9989453
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9989273
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9985682
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993771
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9984946
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99887687
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99907315
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99901617
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9989697
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99889
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99929667
# FPS 31.2
# 1/1 [==============================] - 0s 3ms/step
# 0.999318
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.999419
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99922776
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9993992
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9992342
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9993642
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.999302
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9993831
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.99942976
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99927896
# FPS 32.2
# 1/1 [==============================] - 0s 3ms/step
# 0.9994049
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99941623
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.9993374
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.999244
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9989774
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9987436
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9988914
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9993315
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99925715
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9994783
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9994367
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99960536
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9995409
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99957794
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9996284
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99955386
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99949324
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.99951875
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9995127
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9994925
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99946696
# FPS 31.2
# 1/1 [==============================] - 0s 5ms/step
# 0.9993249
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99941385
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99947804
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99947673
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99935347
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992895
# FPS 40.0
# 1/1 [==============================] - 0s 4ms/step
# 0.9992387
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99933285
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9994723
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99933666
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99923074
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9992562
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.9992493
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9992009
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99941933
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9992612
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9989274
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99913836
# FPS 37.0
# 1/1 [==============================] - 0s 4ms/step
# 0.99863356
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99919194
# FPS 35.7
# 1/1 [==============================] - 0s 5ms/step
# 0.9994711
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99911755
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99882525
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.9986866
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9991353
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.9988337
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99925977
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99944407
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99949014
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9996412
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.9994165
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9995135
# FPS 33.3
# 1/1 [==============================] - 0s 5ms/step
# 0.99932206
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9990552
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99917465
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9993315
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99937695
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99963343
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.9996171
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99927336
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99930143
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99955195
# FPS 38.4
# 1/1 [==============================] - 0s 4ms/step
# 0.9994103
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99878305
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9985025
# FPS 35.7
# 1/1 [==============================] - 0s 3ms/step
# 0.99852955
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9985128
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9987281
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9986319
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99865675
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9989593
# FPS 32.3
# 1/1 [==============================] - 0s 5ms/step
# 0.9988324
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9984302
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99878544
# FPS 37.0
# 1/1 [==============================] - 0s 5ms/step
# 0.998743
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99884427
# FPS 34.5
# 1/1 [==============================] - 0s 3ms/step
# 0.99917346
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9993907
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99907446
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99877375
# FPS 30.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9988128
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9985935
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99861777
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.99860555
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99845886
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9982254
# FPS 40.0
# 1/1 [==============================] - 0s 5ms/step
# 0.9987722
# FPS 32.2
# 1/1 [==============================] - 0s 3ms/step
# 0.99872714
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.99901676
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9985863
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9984351
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.99832696
# FPS 32.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9981021
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9980324
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.0001542492
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99837154
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.9982668
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9983949
# FPS 38.5
# 1/1 [==============================] - 0s 4ms/step
# 0.9986047
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9987275
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99916625
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.9985953
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.99807954
# FPS 34.5
# 1/1 [==============================] - 0s 5ms/step
# 0.00014715536
# *** No ball detected ***
# FPS 32.2
# 1/1 [==============================] - 0s 4ms/step
# 0.0001477491
# *** No ball detected ***
# FPS 33.3
# 1/1 [==============================] - 0s 4ms/step
# 0.00014522599
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014833297
# *** No ball detected ***
# FPS 34.5
# 1/1 [==============================] - 0s 4ms/step
# 0.00014585936
# *** No ball detected ***
# FPS 35.7
# 1/1 [==============================] - 0s 4ms/step
# 0.00014929177
# *** No ball detected ***
# FPS 34.5
